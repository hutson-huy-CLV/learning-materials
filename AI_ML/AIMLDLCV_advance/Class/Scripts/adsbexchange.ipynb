# %%
import pandas as pd
import json
import requests

url = 'https://samples.adsbexchange.com/readsb-hist/2024/07/01/000000Z.json.gz'
r = requests.get(url, allow_redirects=True)

data = json.loads(r.content)
data.keys()
# Out:
# dict_keys(['now', 'messages', 'aircraft'])

# %%
data_aircraft = pd.DataFrame(data['aircraft'])
data_aircraft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11802 entries, 0 to 11801
# Data columns (total 58 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   hex               11802 non-null  object
#  1   type              11802 non-null  object
#  2   flight            10155 non-null  object
#  3   r                 10455 non-null  object
#  4   t                 10402 non-null  object
#  5   alt_baro          11238 non-null  object
#  6   gs                10625 non-null  float64
#  7   track             9657 non-null   float64
#  8   baro_rate         7534 non-null   float64
#  9   squawk            9734 non-null   object
#  10  category          10214 non-null  object
#  11  lat               10601 non-null  float64
#  12  lon               10601 non-null  float64
#  13  nic               10601 non-null  float64
#  14  rc                10601 non-null  float64
#  15  seen_pos          10601 non-null  float64
# ...

# %%
data_aircraft.head()
# Out:
#       hex       type    flight       r     t alt_baro     gs   track  \
# 0  a4ce71      other  DAL197    N409DX  A339    36000  481.0  266.00
# 1  86e822  adsb_icao  ANA113    JA876A  B789    35975    NaN     NaN
# 2  a2a3b6  adsb_icao  UAL143    N26967  B789    38000  504.9  243.79
# 3  a21679      other       NaN  N2333U  B77W    32000  512.0  254.00
# 4  8695a4  adsb_icao  ANA11     JA797A  B77W    34000  507.7  248.39
#
#    baro_rate squawk  ... oat  tat  roll  track_rate  gpsOkBefore  gpsOkLat  \
# 0        0.0   6665  ... NaN  NaN   NaN         NaN          NaN       NaN
# 1        NaN   1442  ... NaN  NaN   NaN         NaN          NaN       NaN
# 2        NaN   1733  ... NaN  NaN   NaN         NaN          NaN       NaN
# 3        0.0   3774  ... NaN  NaN   NaN         NaN          NaN       NaN
# 4        0.0    NaN  ... NaN  NaN   NaN         NaN          NaN       NaN
#
#   gpsOkLon rr_lat  rr_lon  lastPosition
# 0      NaN    NaN     NaN           NaN
# ...
